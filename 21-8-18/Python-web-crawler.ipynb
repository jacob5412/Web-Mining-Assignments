# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Aug 21 17:44:57 2018

@author: jacobjohn

Source: https://notawful.org/basic-python-web-crawler/
"""

#scrapping the web using BeautifulSoup

import requests
from bs4 import BeautifulSoup
def web(page,WebUrl):
    if(page>0):
        url = WebUrl
        code = requests.get(url)
        plain = code.text
        s = BeautifulSoup(plain, "html.parser")
        for link in s.findAll('a',{'class':'post-card-content-link'}):
            tet = link.get('href')
            print("href " + tet)
            url_low = WebUrl + tet
            code_low = requests.get(url_low)
            plain_low = code_low.text
            s_low = BeautifulSoup(plain_low, "html.parser")
            for img in s_low.findAll('img'):
                tet_low = img.get('src')
                print(tet_low)

web(1,'https://notawful.org')
# Out:
# href /hotkeys-shortcuts-commands/
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /data-security-while-traveling/
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /installing-and-troubleshooting-netbox/
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /basic-python-web-crawler/
# /content/images/2018/08/webcrawl1-chromeconsole.png
# /content/images/2018/08/webcrawl2-imgtag.png
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /college-university-guide/
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /fixing-ghost-on-digitalocean/
# https://assets.digitalocean.com/articles/pdocs/site/control-panel/networking/domains/no-domains-yet.png
# https://assets.digitalocean.com/articles/putty_do_keys/new_ssh_key_prompt.png
# https://assets.digitalocean.com/articles/pdocs/site/control-panel/droplets/n-choose-image.png
# https://pbs.twimg.com/media/DaMLUoGXUAI21V6.jpg:large
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /conference-travel-advice/
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /gogs-install/
# /content/images/2018/07/gogs-denied.png
# /content/images/2018/07/gogs-denied2.png
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /online-presence-on-a-budget/
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /sr-part2/
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /sr-part1/
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /strava/
# https://pbs.twimg.com/media/DUp9AABW0AA82cI.jpg:large
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /defcon-travel-advice/
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /windows-pki/
# /content/images/2018/07/PKI-DomainMap.jpg
# /content/images/2018/07/SelectRoles.png
# /content/images/2018/07/role-services-window.png
# /content/images/2018/07/adcsconfigurationwindow.png
# /content/images/2018/07/rootcaCryptography.png
# /content/images/2018/07/rootCAName.png
# /content/images/2018/07/rootConfirmation.png
# /content/images/2018/07/rootCAProperties.png
# /content/images/2018/07/rootAIA.png
# /content/images/2018/07/rootCDP.png
# /content/images/2018/07/rootfiles.png
# /content/images/2018/07/subadcswarning.png
# /content/images/2018/07/submitarequest.png
# /content/images/2018/07/seerequest.png
# /content/images/2018/07/issuerequest.png
# /content/images/2018/07/export.png
# /content/images/2018/07/trustedrootinstall.png
# /content/images/2018/07/install-CA-certificate.png
# /content/images/2018/07/certtemplatecomputer.png
# /content/images/2018/07/certtemplatecomputersecurity.png
# /content/images/2018/07/group-policy-object.png
# /content/images/2018/07/certificates.png
# /content/images/2018/07/revoked.png
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /engineering-journals/
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /why-i-hate-mathematicians/
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /lessons-learned-october-2017/
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
# href /password-managers/
# https://imgs.xkcd.com/comics/security.png
# /content/images/2018/07/headshot.jpg
# /content/images/2018/07/headshot.jpg
